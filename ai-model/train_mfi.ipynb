# %% [markdown]
# # NeuroBalance MFI Training Notebook
# This notebook uses mock data to illustrate a training pipeline.

# %%
import numpy as np
import pandas as pd
np.random.seed(0)
data = pd.DataFrame({
    'stress_score': np.random.randint(1, 10, 100),
    'sleep_hours': np.random.normal(7, 1.5, 100),
    'activity_level': np.random.randint(1, 5, 100)
})
data.head()
